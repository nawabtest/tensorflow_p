# %% [markdown]
# <a href="https://colab.research.google.com/github/nawabtest/tensorflow_p/blob/dev/Copy_of_Malaria_Detection_by_Neuralearn_ai_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

# %%
dataset, dataset_info = tfds.load("malaria", with_info=True)

# %%
dataset, dataset_info = tfds.load("malaria", with_info=True, split=['train[:80%]','train[80%:90%]','train[90%:]'], shuffle_files = True)

# %%
dataset
# Out:
# [<_PrefetchDataset element_spec={'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>,
#  <_PrefetchDataset element_spec={'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>,
#  <_PrefetchDataset element_spec={'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>]

# %%
train_dataset = dataset[0]
val_dataset = dataset[1]
test_dataset = dataset[2]

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 22046
# 2756
# 2756

# %%
len(dataset["train"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-9e008e0c9d25> in <cell line: 0>()
# ----> 1 len(dataset["train"])
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in dataset["train"].take(1):
 print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b4af6f81ee9e> in <cell line: 0>()
# ----> 1 for i in dataset["train"].take(1):
#       2  print(i)
#
# TypeError: list indices must be integers or slices, not str

# %%
dataset_info

# %%
def split(dataset,TRAIN_RATIO, VAL_RATIO, TEST_RATIO):
  DATASET_SIZE = len(dataset)

  train_ds = ds.take(int(TRAIN_RATIO*DATASET_SIZE))
  val_test_ds = ds.skip(int(TRAIN_RATIO*DATASET_SIZE))
  val_ds = val_test_ds.take(int(VAL_RATIO*DATASET_SIZE))
  test_ds = val_test_ds.skip(int(VAL_RATIO*DATASET_SIZE))

  return train_ds, val_ds, test_ds

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.2
TEST_RATIO = 0.2
train_ds, val_ds, test_ds = split(dataset, TRAIN_RATIO, VAL_RATIO, TEST_RATIO)

# %%
train_dataset = dataset[0]
val_dataset = dataset[1]
test_dataset = dataset[2]

# %%
print(len(train_dataset), len(train_ds))
print(len(val_dataset), len(val_ds))
print(len(test_dataset), len(test_ds))

# %%
for i in val_dataset.take(1):
  print(i)
